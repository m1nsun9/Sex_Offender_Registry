# %%
import pandas as pd
import math
from sqlalchemy import create_engine
from config import password
import os

# %%
# import csv file
data = pd.read_csv("Sex_Offender_Registry.csv")

# %%
# display full data in table
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#               X          Y  OBJECTID  BLOCK_X  BLOCK_Y  \
# 0    -76.973974  38.863542   4236689   402259   132858
# 1    -76.972648  38.857499   4236690   402374   132187
# 2    -76.971451  38.932130   4236691   402476   140472
# 3    -77.010605  38.914089   4236692   399080   138468
# 4    -77.021917  38.913356   4236693   398099   138387
# ...         ...        ...       ...      ...      ...
# 1318 -76.991535  38.878848   4237792   400735   134556
# 1319 -76.972864  38.868251   4237793   402355   133380
# 1320 -76.965604  38.874895   4237794   402985   134118
# 1321 -76.935537  38.881093   4237795   405593   134808
# 1322 -76.959117  38.873312   4237796   403548   133943
#
#             DCS_LAST_MOD_DTM SEXOFFENDERCODE                 ADDDATE  \
# 0     2021/01/14 06:15:24+00         002-910  2016/08/02 09:34:44+00
# 1     2021/01/14 06:15:24+00         002-913  2016/08/04 14:42:53+00
# 2     2021/01/14 06:15:24+00         002-919  2016/08/09 18:06:15+00
# 3     2021/01/14 06:15:24+00         002-927  2016/08/30 11:29:37+00
# 4     2021/01/14 06:15:24+00         002-928  2016/08/31 10:07:09+00
# ...                      ...             ...                     ...
# 1318  2021/01/14 06:15:24+00         001-555  2012/08/06 11:18:48+00
# 1319  2021/01/14 06:15:24+00         001-555  2012/08/06 11:18:48+00
# 1320  2021/01/14 06:15:24+00         001-559  2011/04/07 15:02:37+00
# 1321  2021/01/14 06:15:24+00         001-559  2011/04/07 15:02:37+00
# 1322  2021/01/14 06:15:24+00         001-563  2012/12/10 00:00:00+00
#
#         LASTNAME  FIRSTNAME  \
# 0        SANDERS    ANTHONY
# 1         GAYLES   JERMAINE
# 2         HARRIS   REGINALD
# 3     STRICKLAND       GARY
# 4           GANT    TIMOTHY
# ...          ...        ...
# 1318     JENKINS  MARQUETTE
# 1319     JENKINS  MARQUETTE
# 1320  WASHINGTON   LAWRENCE
# 1321  WASHINGTON   LAWRENCE
# 1322        TYER       JOHN
#
#                                                 ALIASES MAXCLASSIFICATION  \
# 0     DERRICK  JUICE / X  JUICE / ANTHONY  SANDERS /...                 A
# 1     ROBERT  GAYLES / JERMAINE  IRVIN / JERMAINE  I...                 B
# 2                          REGINALD ELBERT HARRIS-WILLS                 B
# 3                                                MELVIN                 B
# 4                                         TIMOTHY  GANT                 B
# ...                                                 ...               ...
# 1318                            MARQUETTE KEVON JENKINS                 A
# 1319                            MARQUETTE KEVON JENKINS                 A
# 1320                           LAWRENE LEWIS WASHINGTON                 B
# 1321                           LAWRENE LEWIS WASHINGTON                 B
# 1322                                                NaN                 A
#
#                    BIRTHDATE  HEIGHTNUM  WEIGHTNUM EYECOLOR   HAIRCOLOR  \
# 0     1969/06/19 00:00:00+00         66        138    BROWN       BLACK
# 1     1986/06/25 00:00:00+00         73        200    BROWN       BLACK
# 2     1995/02/12 00:00:00+00         67        157    BROWN       BLACK
# 3     1967/01/22 00:00:00+00         74        245    BROWN       BLACK
# 4     1989/09/19 00:00:00+00         71        285    BROWN       BLACK
# ...                      ...        ...        ...      ...         ...
# 1318  1991/04/23 00:00:00+00         66        205    BROWN       BLACK
# 1319  1991/04/23 00:00:00+00         66        205    BROWN       BLACK
# 1320  1982/06/05 00:00:00+00         70        165    BROWN       BLACK
# 1321  1982/06/05 00:00:00+00         70        165    BROWN       BLACK
# 1322  1951/08/18 00:00:00+00         71        160    BROWN  BLACK/GRAY
#
#                                                MARKINGS  \
# 0     TATTOO-LEFT WRIST: CHINESE SYMBOL; RIGHT WRIST...
# 1                                                   NaN
# 2     TATTOO ON LOWER RIGHT ARM "LAMONT"; TATTOO ON ...
# 3     TATTOO ON SHOULDER "TINA"; GUNSHOT WOUNDS ON B...
# 4     TATTOO ON LEFT SHOULDER 'PICTURE OF A CROSS WI...
# ...                                                 ...
# 1318                                                NaN
# 1319                                                NaN
# 1320                                                NaN
# 1321                                                NaN
# 1322                                                NaN
#
#             REGISTRATIONDATE  TYPE  DISTRICT    PSA  \
# 0     2016/08/29 00:00:00+00  HOME       6.0  607.0
# 1     2018/02/22 00:00:00+00  HOME       7.0  701.0
# 2     2016/10/20 00:00:00+00  HOME       5.0  503.0
# 3     2016/09/01 00:00:00+00  HOME       3.0  308.0
# 4     2017/02/09 00:00:00+00  WORK       3.0  308.0
# ...                      ...   ...       ...    ...
# 1318  2012/08/23 00:00:00+00  WORK       1.0  106.0
# 1319  2012/08/23 00:00:00+00  HOME       6.0  607.0
# 1320  2011/04/18 00:00:00+00  WORK       6.0  605.0
# 1321  2011/04/18 00:00:00+00  HOME       6.0  604.0
# 1322  2007/04/04 00:00:00+00  HOME       6.0  605.0
#
#                                     BLOCKNAME QUADRANT    ZIP
# 0      2300 - 2399 BLOCK OF GOOD HOPE ROAD SE       SE  20020
# 1        2300 - 2399 BLOCK OF AINGER PLACE SE       SE  20020
# 2     2400 - 2499 BLOCK OF LAWRENCE STREET NE       NE  20018
# 3                 1 - 99 BLOCK OF S STREET NW       NW  20001
# 4          1700 - 1799 BLOCK OF 7TH STREET NW       NW  20001
# ...                                       ...      ...    ...
# 1318        800 - 999 BLOCK OF 11TH STREET SE       SE  20003
# 1319         2238 - 2399 BLOCK OF S STREET SE       SE  20020
# 1320   1300 - 1349 BLOCK OF ANACOSTIA ROAD SE       SE  20019
# 1321         600 - 699 BLOCK OF 46TH PLACE SE       SE  20019
# 1322      3200 - 3399 BLOCK OF POPE STREET SE       SE  20020
#
# [1323 rows x 25 columns]

# %%
# change datetime format to only include date
clean_data = data

for i in range(len(clean_data)):
    clean_data.iloc[i, 5] = clean_data.iloc[i, 5][:10]
    clean_data.iloc[i, 7] = clean_data.iloc[i, 7][:10]
    clean_data.iloc[i, 12] = clean_data.iloc[i, 12][:10]
    clean_data.iloc[i, 18] = clean_data.iloc[i, 18][:10]
    if math.isnan(clean_data.iloc[i, 20]):
        pass
    else:
        clean_data.iloc[i, 20] = int(clean_data.iloc[i, 20])

# %%
clean_data = clean_data.rename(columns={
    'X': 'Longitude',
    'Y': 'Latitude',
    'OBJECTID': 'Object_ID',
    'BLOCK_X': 'Block_X',
    'BLOCK_Y': 'Block_Y',
    'DCS_LAST_MOD_DTM': 'Last_Updated',
    'SEXOFFENDERCODE': 'Sex_Offender_Code',
    'ADDDATE': 'Date_Added',
    'LASTNAME': 'Last_Name',
    'FIRSTNAME': 'First_Name',
    'ALIASES': 'Aliases',
    'MAXCLASSIFICATION': 'Max_Classification',
    'BIRTHDATE': 'DOB',
    'HEIGHTNUM': 'Height_Inches',
    'WEIGHTNUM': 'Weight_lbs',
    'EYECOLOR': 'Eye_Color',
    'HAIRCOLOR': 'Hair_Color',
    'MARKINGS': 'Markings',
    'REGISTRATIONDATE': 'Date_Registered',
    'TYPE': 'Residence',
    'DISTRICT': 'District',
    'PSA': 'PSA_Announcement_Number',
    'BLOCKNAME': 'Block_Address',
    'QUADRANT': 'Quadrant',
    'ZIP': 'ZIP_Code'
})

# %%
clean_data
# Out:
#       Longitude   Latitude  Object_ID  Block_X  Block_Y Last_Updated  \
# 0    -76.973974  38.863542    4236689   402259   132858   2021/01/14
# 1    -76.972648  38.857499    4236690   402374   132187   2021/01/14
# 2    -76.971451  38.932130    4236691   402476   140472   2021/01/14
# 3    -77.010605  38.914089    4236692   399080   138468   2021/01/14
# 4    -77.021917  38.913356    4236693   398099   138387   2021/01/14
# ...         ...        ...        ...      ...      ...          ...
# 1318 -76.991535  38.878848    4237792   400735   134556   2021/01/14
# 1319 -76.972864  38.868251    4237793   402355   133380   2021/01/14
# 1320 -76.965604  38.874895    4237794   402985   134118   2021/01/14
# 1321 -76.935537  38.881093    4237795   405593   134808   2021/01/14
# 1322 -76.959117  38.873312    4237796   403548   133943   2021/01/14
#
#      Sex_Offender_Code  Date_Added   Last_Name First_Name  \
# 0              002-910  2016/08/02     SANDERS    ANTHONY
# 1              002-913  2016/08/04      GAYLES   JERMAINE
# 2              002-919  2016/08/09      HARRIS   REGINALD
# 3              002-927  2016/08/30  STRICKLAND       GARY
# 4              002-928  2016/08/31        GANT    TIMOTHY
# ...                ...         ...         ...        ...
# 1318           001-555  2012/08/06     JENKINS  MARQUETTE
# 1319           001-555  2012/08/06     JENKINS  MARQUETTE
# 1320           001-559  2011/04/07  WASHINGTON   LAWRENCE
# 1321           001-559  2011/04/07  WASHINGTON   LAWRENCE
# 1322           001-563  2012/12/10        TYER       JOHN
#
#                                                 Aliases Max_Classification  \
# 0     DERRICK  JUICE / X  JUICE / ANTHONY  SANDERS /...                  A
# 1     ROBERT  GAYLES / JERMAINE  IRVIN / JERMAINE  I...                  B
# 2                          REGINALD ELBERT HARRIS-WILLS                  B
# 3                                                MELVIN                  B
# 4                                         TIMOTHY  GANT                  B
# ...                                                 ...                ...
# 1318                            MARQUETTE KEVON JENKINS                  A
# 1319                            MARQUETTE KEVON JENKINS                  A
# 1320                           LAWRENE LEWIS WASHINGTON                  B
# 1321                           LAWRENE LEWIS WASHINGTON                  B
# 1322                                                NaN                  A
#
#              DOB  Height_Inches  Weight_lbs Eye_Color  Hair_Color  \
# 0     1969/06/19             66         138     BROWN       BLACK
# 1     1986/06/25             73         200     BROWN       BLACK
# 2     1995/02/12             67         157     BROWN       BLACK
# 3     1967/01/22             74         245     BROWN       BLACK
# 4     1989/09/19             71         285     BROWN       BLACK
# ...          ...            ...         ...       ...         ...
# 1318  1991/04/23             66         205     BROWN       BLACK
# 1319  1991/04/23             66         205     BROWN       BLACK
# 1320  1982/06/05             70         165     BROWN       BLACK
# 1321  1982/06/05             70         165     BROWN       BLACK
# 1322  1951/08/18             71         160     BROWN  BLACK/GRAY
#
#                                                Markings Date_Registered  \
# 0     TATTOO-LEFT WRIST: CHINESE SYMBOL; RIGHT WRIST...      2016/08/29
# 1                                                   NaN      2018/02/22
# 2     TATTOO ON LOWER RIGHT ARM "LAMONT"; TATTOO ON ...      2016/10/20
# 3     TATTOO ON SHOULDER "TINA"; GUNSHOT WOUNDS ON B...      2016/09/01
# 4     TATTOO ON LEFT SHOULDER 'PICTURE OF A CROSS WI...      2017/02/09
# ...                                                 ...             ...
# 1318                                                NaN      2012/08/23
# 1319                                                NaN      2012/08/23
# 1320                                                NaN      2011/04/18
# 1321                                                NaN      2011/04/18
# 1322                                                NaN      2007/04/04
#
#      Residence  District  PSA_Announcement_Number  \
# 0         HOME       6.0                    607.0
# 1         HOME       7.0                    701.0
# 2         HOME       5.0                    503.0
# 3         HOME       3.0                    308.0
# 4         WORK       3.0                    308.0
# ...        ...       ...                      ...
# 1318      WORK       1.0                    106.0
# 1319      HOME       6.0                    607.0
# 1320      WORK       6.0                    605.0
# 1321      HOME       6.0                    604.0
# 1322      HOME       6.0                    605.0
#
#                                 Block_Address Quadrant  ZIP_Code
# 0      2300 - 2399 BLOCK OF GOOD HOPE ROAD SE       SE     20020
# 1        2300 - 2399 BLOCK OF AINGER PLACE SE       SE     20020
# 2     2400 - 2499 BLOCK OF LAWRENCE STREET NE       NE     20018
# 3                 1 - 99 BLOCK OF S STREET NW       NW     20001
# 4          1700 - 1799 BLOCK OF 7TH STREET NW       NW     20001
# ...                                       ...      ...       ...
# 1318        800 - 999 BLOCK OF 11TH STREET SE       SE     20003
# 1319         2238 - 2399 BLOCK OF S STREET SE       SE     20020
# 1320   1300 - 1349 BLOCK OF ANACOSTIA ROAD SE       SE     20019
# 1321         600 - 699 BLOCK OF 46TH PLACE SE       SE     20019
# 1322      3200 - 3399 BLOCK OF POPE STREET SE       SE     20020
#
# [1323 rows x 25 columns]

# %%
# Clean dataset to only include unique offenders
no_duplicate_data = clean_data.drop_duplicates(subset=['Sex_Offender_Code'])

# %%
# export dataset with unique add dates for line chart
no_duplicate_data.to_csv("unique_add_dates.csv")
no_duplicate_data.head()
# Out:
#    Longitude   Latitude  Object_ID  Block_X  Block_Y Last_Updated  \
# 0 -76.973974  38.863542    4236689   402259   132858   2021/01/14
# 1 -76.972648  38.857499    4236690   402374   132187   2021/01/14
# 2 -76.971451  38.932130    4236691   402476   140472   2021/01/14
# 3 -77.010605  38.914089    4236692   399080   138468   2021/01/14
# 4 -77.021917  38.913356    4236693   398099   138387   2021/01/14
#
#   Sex_Offender_Code  Date_Added   Last_Name First_Name  \
# 0           002-910  2016/08/02     SANDERS    ANTHONY
# 1           002-913  2016/08/04      GAYLES   JERMAINE
# 2           002-919  2016/08/09      HARRIS   REGINALD
# 3           002-927  2016/08/30  STRICKLAND       GARY
# 4           002-928  2016/08/31        GANT    TIMOTHY
#
#                                              Aliases Max_Classification  \
# 0  DERRICK  JUICE / X  JUICE / ANTHONY  SANDERS /...                  A
# 1  ROBERT  GAYLES / JERMAINE  IRVIN / JERMAINE  I...                  B
# 2                       REGINALD ELBERT HARRIS-WILLS                  B
# 3                                             MELVIN                  B
# 4                                      TIMOTHY  GANT                  B
#
#           DOB  Height_Inches  Weight_lbs Eye_Color Hair_Color  \
# 0  1969/06/19             66         138     BROWN      BLACK
# 1  1986/06/25             73         200     BROWN      BLACK
# 2  1995/02/12             67         157     BROWN      BLACK
# 3  1967/01/22             74         245     BROWN      BLACK
# 4  1989/09/19             71         285     BROWN      BLACK
#
#                                             Markings Date_Registered  \
# 0  TATTOO-LEFT WRIST: CHINESE SYMBOL; RIGHT WRIST...      2016/08/29
# 1                                                NaN      2018/02/22
# 2  TATTOO ON LOWER RIGHT ARM "LAMONT"; TATTOO ON ...      2016/10/20
# 3  TATTOO ON SHOULDER "TINA"; GUNSHOT WOUNDS ON B...      2016/09/01
# 4  TATTOO ON LEFT SHOULDER 'PICTURE OF A CROSS WI...      2017/02/09
#
#   Residence  District  PSA_Announcement_Number  \
# 0      HOME       6.0                    607.0
# 1      HOME       7.0                    701.0
# 2      HOME       5.0                    503.0
# 3      HOME       3.0                    308.0
# 4      WORK       3.0                    308.0
#
#                              Block_Address Quadrant  ZIP_Code
# 0   2300 - 2399 BLOCK OF GOOD HOPE ROAD SE       SE     20020
# 1     2300 - 2399 BLOCK OF AINGER PLACE SE       SE     20020
# 2  2400 - 2499 BLOCK OF LAWRENCE STREET NE       NE     20018
# 3              1 - 99 BLOCK OF S STREET NW       NW     20001
# 4       1700 - 1799 BLOCK OF 7TH STREET NW       NW     20001

# %% [markdown]
# ## Export data into SQL

# %%
rds_connection_string = f"postgres:{password}@localhost:5432/sex_offender_db"
engine = create_engine(f"postgresql://{rds_connection_string}")

# %%
engine.table_names()
# Out:
# ['registry', 'unique_dates']

# %%
clean_data.to_sql(name='registry', con=engine, if_exists='append', index=False)
no_duplicate_data.to_sql(name='unique_dates', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UniqueViolation: duplicate key value violates unique constraint "pk_registry"
# DETAIL:  Key ("Object_ID")=(4236689) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-33-bba73228edc3> in <module>
# ----> 1 clean_data.to_sql(name='registry', con=engine, if_exists='append', index=False)
#       2 no_duplicate_data.to_sql(name='unique_dates', con=engine, if_exists='append', index=False)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                             break
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#    1259                     )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "pk_registry"
# DETAIL:  Key ("Object_ID")=(4236689) already exists.
#
# [SQL: INSERT INTO registry ("Longitude", "Latitude", "Object_ID", "Block_X", "Block_Y", "Last_Updated", "Sex_Offender_Code", "Date_Added", "Last_Name", "First_Name", "Aliases", "Max_Classification", "DOB", "Height_Inches", "Weight_lbs", "Eye_Color", "Hair_Color", "Markings", "Date_Registered", "Residence", "District", "PSA_Announcement_Number", "Block_Address", "Quadrant", "ZIP_Code") VALUES (%(Longitude)s, %(Latitude)s, %(Object_ID)s, %(Block_X)s, %(Block_Y)s, %(Last_Updated)s, %(Sex_Offender_Code)s, %(Date_Added)s, %(Last_Name)s, %(First_Name)s, %(Aliases)s, %(Max_Classification)s, %(DOB)s, %(Height_Inches)s, %(Weight_lbs)s, %(Eye_Color)s, %(Hair_Color)s, %(Markings)s, %(Date_Registered)s, %(Residence)s, %(District)s, %(PSA_Announcement_Number)s, %(Block_Address)s, %(Quadrant)s, %(ZIP_Code)s)]
# [parameters: ({'Longitude': -76.9739743119999, 'Latitude': 38.8635423394491, 'Object_ID': 4236689, 'Block_X': 402259, 'Block_Y': 132858, 'Last_Updated': '2021/01/14', 'Sex_Offender_Code': '002-910', 'Date_Added': '2016/08/02', 'Last_Name': 'SANDERS', 'First_Name': 'ANTHONY', 'Aliases': 'DERRICK  JUICE / X  JUICE / ANTHONY  SANDERS / ANTHONY D SANDERS / ANTHONY DERRECK SANDERS / DERRICK  SANDERS / JUICE  SANDERS / WHISKEY  SANDERS / WHISKEY  SANDERS / ANTHONY  SAUNDERS / ANTHONY DERRICK SAUNDERS / DERRICK  SAUNDERS / JUICE  SAUNDERS / X', 'Max_Classification': 'A', 'DOB': '1969/06/19', 'Height_Inches': 66, 'Weight_lbs': 138, 'Eye_Color': 'BROWN', 'Hair_Color': 'BLACK', 'Markings': 'TATTOO-LEFT WRIST: CHINESE SYMBOL; RIGHT WRIST-CHINESE SYMBOL TATTOO WRIST, RIGHT / TATTOO WRIST, LEFT', 'Date_Registered': '2016/08/29', 'Residence': 'HOME', 'District': 6.0, 'PSA_Announcement_Number': 607.0, 'Block_Address': '2300 - 2399 BLOCK OF GOOD HOPE ROAD SE', 'Quadrant': 'SE', 'ZIP_Code': 20020}, {'Longitude': -76.972648106514, 'Latitude': 38.857499456770796, 'Object_ID': 4236690, 'Block_X': 402374, 'Block_Y': 132187, 'Last_Updated': '2021/01/14', 'Sex_Offender_Code': '002-913', 'Date_Added': '2016/08/04', 'Last_Name': 'GAYLES', 'First_Name': 'JERMAINE', 'Aliases': 'ROBERT  GAYLES / JERMAINE  IRVIN / JERMAINE  IRVING / JERMAINE BRANDON IRVING / JERMAINE B IRVING', 'Max_Classification': 'B', 'DOB': '1986/06/25', 'Height_Inches': 73, 'Weight_lbs': 200, 'Eye_Color': 'BROWN', 'Hair_Color': 'BLACK', 'Markings': None, 'Date_Registered': '2018/02/22', 'Residence': 'HOME', 'District': 7.0, 'PSA_Announcement_Number': 701.0, 'Block_Address': '2300 - 2399 BLOCK OF AINGER PLACE SE', 'Quadrant': 'SE', 'ZIP_Code': 20020}, {'Longitude': -76.9714511471898, 'Latitude': 38.932129899085105, 'Object_ID': 4236691, 'Block_X': 402476, 'Block_Y': 140472, 'Last_Updated': '2021/01/14', 'Sex_Offender_Code': '002-919', 'Date_Added': '2016/08/09', 'Last_Name': 'HARRIS', 'First_Name': 'REGINALD', 'Aliases': 'REGINALD ELBERT HARRIS-WILLS', 'Max_Classification': 'B', 'DOB': '1995/02/12', 'Height_Inches': 67, 'Weight_lbs': 157, 'Eye_Color': 'BROWN', 'Hair_Color': 'BLACK', 'Markings': 'TATTOO ON LOWER RIGHT ARM "LAMONT"; TATTOO ON UPPER RIGHT ARM "F.O.E" TATTOO ON RIGHT HAND "ANGEL"; TATTOO ON LOWER LEFT ARM "RIP KAWON" & "REDZ" TATTOO ARM, LEFT / TATTOO ARM, RIGHT / SCAR ARM, RIGHT / PIERCED EARS / TATTOO HAND, RIGHT', 'Date_Registered': '2016/10/20', 'Residence': 'HOME', 'District': 5.0, 'PSA_Announcement_Number': 503.0, 'Block_Address': '2400 - 2499 BLOCK OF LAWRENCE STREET NE', 'Quadrant': 'NE', 'ZIP_Code': 20018}, {'Longitude': -77.0106047845178, 'Latitude': 38.9140885141753, 'Object_ID': 4236692, 'Block_X': 399080, 'Block_Y': 138468, 'Last_Updated': '2021/01/14', 'Sex_Offender_Code': '002-927', 'Date_Added': '2016/08/30', 'Last_Name': 'STRICKLAND', 'First_Name': 'GARY', 'Aliases': 'MELVIN', 'Max_Classification': 'B', 'DOB': '1967/01/22', 'Height_Inches': 74, 'Weight_lbs': 245, 'Eye_Color': 'BROWN', 'Hair_Color': 'BLACK', 'Markings': 'TATTOO ON SHOULDER "TINA"; GUNSHOT WOUNDS ON BACK AND LOWER LEFT LEG TATTOO SHOULDER, RIGHT / SCAR FOREHEAD / GLASSES / SCAR BACK / SCAR LEG, LEFT', 'Date_Registered': '2016/09/01', 'Residence': 'HOME', 'District': 3.0, 'PSA_Announcement_Number': 308.0, 'Block_Address': '1 - 99 BLOCK OF S STREET NW', 'Quadrant': 'NW', 'ZIP_Code': 20001}, {'Longitude': -77.0219173366836, 'Latitude': 38.91335618331539, 'Object_ID': 4236693, 'Block_X': 398099, 'Block_Y': 138387, 'Last_Updated': '2021/01/14', 'Sex_Offender_Code': '002-928', 'Date_Added': '2016/08/31', 'Last_Name': 'GANT', 'First_Name': 'TIMOTHY', 'Aliases': 'TIMOTHY  GANT', 'Max_Classification': 'B', 'DOB': '1989/09/19', 'Height_Inches': 71, 'Weight_lbs': 285, 'Eye_Color': 'BROWN', 'Hair_Color': 'BLACK', 'Markings': 'TATTOO ON LEFT SHOULDER \'PICTURE OF A CROSS WITH A CROWN WITH THUG LIFE WRITING"; TATTOO ON RIGHT ARM "PICTURE OF MICROPHONES TATTOO SHOULDER, LEFT / TATTOO ARM, RIGHT / PIERCED  ...
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %% [markdown]
# ## df to html

# %%
# clean up df further for table
no_duplicate_data = no_duplicate_data.drop(columns=['Object_ID', 'Longitude', 'Latitude', 'Block_X', 'Block_Y',
                                            'Last_Updated', 'Date_Added', 'District', 'PSA_Announcement_Number',
                                           'Quadrant'])
no_duplicate_data.head()
# Out:
#   Sex_Offender_Code   Last_Name First_Name  \
# 0           002-910     SANDERS    ANTHONY
# 1           002-913      GAYLES   JERMAINE
# 2           002-919      HARRIS   REGINALD
# 3           002-927  STRICKLAND       GARY
# 4           002-928        GANT    TIMOTHY
#
#                                              Aliases Max_Classification  \
# 0  DERRICK  JUICE / X  JUICE / ANTHONY  SANDERS /...                  A
# 1  ROBERT  GAYLES / JERMAINE  IRVIN / JERMAINE  I...                  B
# 2                       REGINALD ELBERT HARRIS-WILLS                  B
# 3                                             MELVIN                  B
# 4                                      TIMOTHY  GANT                  B
#
#           DOB  Height_Inches  Weight_lbs Eye_Color Hair_Color  \
# 0  1969/06/19             66         138     BROWN      BLACK
# 1  1986/06/25             73         200     BROWN      BLACK
# 2  1995/02/12             67         157     BROWN      BLACK
# 3  1967/01/22             74         245     BROWN      BLACK
# 4  1989/09/19             71         285     BROWN      BLACK
#
#                                             Markings Date_Registered  \
# 0  TATTOO-LEFT WRIST: CHINESE SYMBOL; RIGHT WRIST...      2016/08/29
# 1                                                NaN      2018/02/22
# 2  TATTOO ON LOWER RIGHT ARM "LAMONT"; TATTOO ON ...      2016/10/20
# 3  TATTOO ON SHOULDER "TINA"; GUNSHOT WOUNDS ON B...      2016/09/01
# 4  TATTOO ON LEFT SHOULDER 'PICTURE OF A CROSS WI...      2017/02/09
#
#   Residence                            Block_Address  ZIP_Code
# 0      HOME   2300 - 2399 BLOCK OF GOOD HOPE ROAD SE     20020
# 1      HOME     2300 - 2399 BLOCK OF AINGER PLACE SE     20020
# 2      HOME  2400 - 2499 BLOCK OF LAWRENCE STREET NE     20018
# 3      HOME              1 - 99 BLOCK OF S STREET NW     20001
# 4      WORK       1700 - 1799 BLOCK OF 7TH STREET NW     20001

# %%
no_duplicate_data = no_duplicate_data.set_index('Sex_Offender_Code')
no_duplicate_data.head()
# Out:
#                     Last_Name First_Name  \
# Sex_Offender_Code
# 002-910               SANDERS    ANTHONY
# 002-913                GAYLES   JERMAINE
# 002-919                HARRIS   REGINALD
# 002-927            STRICKLAND       GARY
# 002-928                  GANT    TIMOTHY
#
#                                                              Aliases  \
# Sex_Offender_Code
# 002-910            DERRICK  JUICE / X  JUICE / ANTHONY  SANDERS /...
# 002-913            ROBERT  GAYLES / JERMAINE  IRVIN / JERMAINE  I...
# 002-919                                 REGINALD ELBERT HARRIS-WILLS
# 002-927                                                       MELVIN
# 002-928                                                TIMOTHY  GANT
#
#                   Max_Classification         DOB  Height_Inches  Weight_lbs  \
# Sex_Offender_Code
# 002-910                            A  1969/06/19             66         138
# 002-913                            B  1986/06/25             73         200
# 002-919                            B  1995/02/12             67         157
# 002-927                            B  1967/01/22             74         245
# 002-928                            B  1989/09/19             71         285
#
#                   Eye_Color Hair_Color  \
# Sex_Offender_Code
# 002-910               BROWN      BLACK
# 002-913               BROWN      BLACK
# 002-919               BROWN      BLACK
# 002-927               BROWN      BLACK
# 002-928               BROWN      BLACK
#
#                                                             Markings  \
# Sex_Offender_Code
# 002-910            TATTOO-LEFT WRIST: CHINESE SYMBOL; RIGHT WRIST...
# 002-913                                                          NaN
# 002-919            TATTOO ON LOWER RIGHT ARM "LAMONT"; TATTOO ON ...
# 002-927            TATTOO ON SHOULDER "TINA"; GUNSHOT WOUNDS ON B...
# 002-928            TATTOO ON LEFT SHOULDER 'PICTURE OF A CROSS WI...
#
#                   Date_Registered Residence  \
# Sex_Offender_Code
# 002-910                2016/08/29      HOME
# 002-913                2018/02/22      HOME
# 002-919                2016/10/20      HOME
# 002-927                2016/09/01      HOME
# 002-928                2017/02/09      WORK
#
#                                              Block_Address  ZIP_Code
# Sex_Offender_Code
# 002-910             2300 - 2399 BLOCK OF GOOD HOPE ROAD SE     20020
# 002-913               2300 - 2399 BLOCK OF AINGER PLACE SE     20020
# 002-919            2400 - 2499 BLOCK OF LAWRENCE STREET NE     20018
# 002-927                        1 - 99 BLOCK OF S STREET NW     20001
# 002-928                 1700 - 1799 BLOCK OF 7TH STREET NW     20001

# %%
#create html table and save to file
no_duplicate_data.to_html('table.html', index=False, classes=['table', 'table-striped', 'table-hover'])
