# %%
import pandas as pd

# %%
# import csv file
data = pd.read_csv("datasources/Sex_Offender_Registry.csv")

# %%
# display full data in table
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#               X          Y  OBJECTID  BLOCK_X  BLOCK_Y  \
# 0    -76.973974  38.863542   4236689   402259   132858
# 1    -76.972648  38.857499   4236690   402374   132187
# 2    -76.971451  38.932130   4236691   402476   140472
# 3    -77.010605  38.914089   4236692   399080   138468
# 4    -77.021917  38.913356   4236693   398099   138387
# ...         ...        ...       ...      ...      ...
# 1318 -76.991535  38.878848   4237792   400735   134556
# 1319 -76.972864  38.868251   4237793   402355   133380
# 1320 -76.965604  38.874895   4237794   402985   134118
# 1321 -76.935537  38.881093   4237795   405593   134808
# 1322 -76.959117  38.873312   4237796   403548   133943
#
#             DCS_LAST_MOD_DTM SEXOFFENDERCODE                 ADDDATE  \
# 0     2021/01/14 06:15:24+00         002-910  2016/08/02 09:34:44+00
# 1     2021/01/14 06:15:24+00         002-913  2016/08/04 14:42:53+00
# 2     2021/01/14 06:15:24+00         002-919  2016/08/09 18:06:15+00
# ...

# %%
# Clean dataset to only include unique offenders
no_duplicate_data = data.drop_duplicates(subset=['SEXOFFENDERCODE'])

# %%
no_duplicate_data.head()
# Out:
#            X          Y  OBJECTID  BLOCK_X  BLOCK_Y        DCS_LAST_MOD_DTM  \
# 0 -76.973974  38.863542   4236689   402259   132858  2021/01/14 06:15:24+00
# 1 -76.972648  38.857499   4236690   402374   132187  2021/01/14 06:15:24+00
# 2 -76.971451  38.932130   4236691   402476   140472  2021/01/14 06:15:24+00
# 3 -77.010605  38.914089   4236692   399080   138468  2021/01/14 06:15:24+00
# 4 -77.021917  38.913356   4236693   398099   138387  2021/01/14 06:15:24+00
#
#   SEXOFFENDERCODE                 ADDDATE    LASTNAME FIRSTNAME  \
# 0         002-910  2016/08/02 09:34:44+00     SANDERS   ANTHONY
# 1         002-913  2016/08/04 14:42:53+00      GAYLES  JERMAINE
# 2         002-919  2016/08/09 18:06:15+00      HARRIS  REGINALD
# 3         002-927  2016/08/30 11:29:37+00  STRICKLAND      GARY
# 4         002-928  2016/08/31 10:07:09+00        GANT   TIMOTHY
#
#                                              ALIASES MAXCLASSIFICATION  \
# ...

# %%
# export dataset with unique add dates for line chart
no_duplicate_data.to_csv("datasources/unique_add_dates.csv")
